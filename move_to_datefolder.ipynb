# %% [markdown]
# ### move raw files

# %%
import os
from pathlib import Path
from datetime import datetime
import _photo_utilities
import _Python_utilities
from pathlib import Path
import exifread
import pyheif
import piexif
import shutil

# %%
BASEDIR = Path("/mnt/photo/")
NEW_files = BASEDIR / "temp_files"

# %%
fullnames = _Python_utilities.getFullnameListOfallFiles(NEW_files)
print("len(fullnames):", len(fullnames))
print("fullnames:", fullnames)
# Out:
# len(fullnames): 9
# fullnames: ['/mnt/photo/temp_files/2019-10-08/0000-00-00_NoModel_AdobePhotoshopCC2015(Macintosh)/00000000-000000_NoModel_AdobePhotoshopCC2015(Macintosh)_00021313_py.jpg', '/mnt/photo/temp_files/2019-10-08/0000-00-00_NoModel_Google/00000000-000000_NoModel_Google_00016761_py.jpg', '/mnt/photo/temp_files/2019-10-08/00000000-000000_OLYMPUS_C3100Z_v374-75_00000001_py.jpg', '/mnt/photo/temp_files/2019-10-08/00000000-000000_OLYMPUS_C3100Z_v374-75_00000002_py.jpg', '/mnt/photo/temp_files/2019-10-08/00000000-000000_OLYMPUS_C3100Z_v374-75_00000003_py.jpg', '/mnt/photo/temp_files/2019-10-08/00000000-000000_OLYMPUS_C3100Z_v374-75_00000004_py.jpg', '/mnt/photo/temp_files/2019-10-08/00000000-000000_OLYMPUS_C3100Z_v374-75_00000005_py.jpg', '/mnt/photo/temp_files/2019-10-08/20191008-014520_00003560_py.mov', '/mnt/photo/temp_files/2019-10-08/20191008-015236_00003562_py.mov']

# %%
ext_names_mov = [".mp4", ".mov", ".3gp", ".avi"]
ext_names_img = [".dng", ".jpg", ".heic", ".cr2"]

# %%
# from hachoir.parser import createParser
# from hachoir.metadata import extractMetadata
# fpath = Path(fullnames[0])
# parser = createParser(str(fpath))
# metadata = extractMetadata(parser)
# if 'creation_date' in metadata :
#     creation_date = metadata.get('creation_date').strftime("%Y%m%d-%H%M%S")
# else : 
#     import os.path, time
#     from dateutil.parser import parse
#     creation_date = parse(time.ctime(os.path.getctime(str(fpath)))).strftime("%Y%m%d-%H%M%S")
# creation_date

# %%
# fpath = Path(fullnames[0])
# heif_file = pyheif.read_heif(str(fpath))
# heif_file
# for metadata in heif_file.metadata or []:
#     if metadata['type'] == 'Exif':
#         exif_dict = piexif.load(metadata['data'])
# image_datetime = exif_dict['0th'][306].decode('utf-8').replace(':','')
# image_datetime = image_datetime.replace(' ','-')
# camera_company = exif_dict['0th'][271].decode('utf-8')
# camera_model = exif_dict['0th'][272].decode('utf-8').replace(' ','-')
# image_Software = "-"
# image_datetime, camera_company, camera_model, image_Software

# %%
# fpath = Path(fullnames[0])
# f = open(str(fpath), 'rb')
# tags = exifread.process_file(f)
# f.close()
# tags
# #tags['EXIF DateTimeOriginal']
# image_datetime = tags['EXIF DateTimeOriginal'].values.replace(':','')
# image_datetime = image_datetime.replace(' ','-')
# image_datetime = image_datetime.replace('오후','')
# image_datetime = image_datetime.replace('오전','')
# image_datetime

# %%
import _photo_utilities
fpath = Path(fullnames[0])
print(fpath)
print(fpath.suffix)
file_datetime, camera_ModelID, Software = _photo_utilities.get_fileInfo_from_file(str(fpath))

print(file_datetime, camera_ModelID, Software)
# Out:
# /mnt/photo/temp_files/2019-10-08/0000-00-00_NoModel_AdobePhotoshopCC2015(Macintosh)/00000000-000000_NoModel_AdobePhotoshopCC2015(Macintosh)_00021313_py.jpg
# .jpg
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_46026/688683694.py in <module>
#       3 print(fpath)
#       4 print(fpath.suffix)
# ----> 5 file_datetime, camera_ModelID, Software = _photo_utilities.get_fileInfo_from_file(str(fpath))
#       6
#       7 print(file_datetime, camera_ModelID, Software)
#
# /mnt/homes/parksparks/Drive/KBox/Github/photo_Python/_photo_utilities.py in get_fileInfo_from_file(fpath)
#     247 #         import os.path, time
#     248 #         from dateutil.parser import parse
# --> 249 #         creation_date = parse(time.ctime(os.path.getctime(fullname))).strftime("%Y%m%d-%H%M%S")
#     250 #     return creation_date
#     251
#
# UnboundLocalError: local variable 'camera_model' referenced before assignment

# %%
fpath = Path(fullnames[0])
image_datetime = _photo_utilities.get_image_datetime_str(str(fpath))
image_ModelID = _photo_utilities.get_image_Model_name(str(fpath)).replace(' ','')
image_Software = _photo_utilities.get_image_Software(str(fpath))
#print("image_datetime :", image_datetime)

image_dt = datetime.strptime(image_datetime, '%Y%m%d-%H%M%S')
# print("image_dt :", image_dt)
# print(f"image_dt.month : {image_dt.month:02d}")
# print(f"image_dt.day : {image_dt.day:02d}")
SAVEDIR = (BASEDIR/ str(image_dt.year) / f'{(image_dt.month):02d}' / f'{(image_dt.day):02d}_{image_ModelID}')
new_fname = f'{image_datetime}_{image_ModelID}_py{fpath.suffix}'
new_fpath = SAVEDIR / new_fname

# %%
# ext = ".AVI"
# fullnames = [x for x in fullnames if ext in x]

# print("len(fullnames):", len(fullnames))
# print("fullnames:", fullnames)

# %%
# fpath = Path(fullnames[0])
# if fpath.suffix.lower() in ext_names_mov :
#     mov_datetime = _photo_utilities.get_mov_creation_date(str(fpath))
#     print("mov_datetime :", mov_datetime)

# %%
# fullnames = _Python_utilities.getFullnameListOfallFiles(NEW_files)
# print("len(fullnames):", len(fullnames))
# print("fullnames:", fullnames)

# %%
# fpath = Path(fullnames[0])
# fpath
# mov_datetime = _photo_utilities.get_mov_creation_date(str(fpath))
# mov_datetime
# mov_dt = datetime.strptime(mov_datetime, '%Y%m%d-%H%M%S')
# SAVEDIR = (BASEDIR/ str(mov_dt.year) / f'{(mov_dt.month):02d}' / f'{(mov_dt.day):02d}')
# new_fname = f'{mov_datetime}_py{fpath.suffix}'
# new_fpath = SAVEDIR / new_fname
# new_fpath.exists()

# %%
# new_date = datetime.strftime(datetime.now(), '%Y%m%d%H%M%S')
# new_fpath = new_fpath.parents[0] / f'{new_fpath.stem}_{new_date}{new_fpath.suffix}'
# new_fpath

# %%
for fullname in fullnames[:]:
    fpath = Path(fullname)
    print(fpath)
    if fpath.suffix.lower() in ext_names_mov :
        try: 
            mov_datetime = _photo_utilities.get_mov_creation_date(str(fpath))
            print("mov_datetime :", mov_datetime)
            mov_dt = datetime.strptime(mov_datetime, '%Y%m%d-%H%M%S')
            # print("mov_dt :", mov_dt)
            # print(f"mov_dt.month : {mov_dt.month:02d}")
            # print(f"mov_dt.day : {mov_dt.day:02d}")
            SAVEDIR = (BASEDIR/ str(mov_dt.year) / f'{(mov_dt.month):02d}' / f'{(mov_dt.day):02d}')
            new_fname = f'{mov_datetime}_py{fpath.suffix}'
            new_fpath = SAVEDIR / new_fname
            print("new_fpath :", new_fpath)
            for i in range(3, -1, -1):
                if not new_fpath.parents[i].exists() :
                    os.mkdir(str(new_fpath.parents[i]))
                    #print(f'{str(new_fpath.parents[i])} is created...')
                else :
                    #print(f'{str(new_fpath.parents[i])} is exist...')
                    pass
            
            if not new_fpath.exists() :
                print(f'{str(new_fpath)} is not exist...')
                shutil.move(str(fpath), str(new_fpath))
            else : 
                print(f'{str(new_fpath)} is already exist...')
                new_date = datetime.strftime(datetime.now(), '%Y%m%d%H%M%S')
                new_fpath = new_fpath.parents[0] / f'{new_fpath.stem}_{new_date}{new_fpath.suffix}'
            shutil.move(str(fpath), str(new_fpath))
        except Exception as err :
            print(err)
            

    if fpath.suffix.lower() in ext_names_img :
        try: 
            image_datetime = _photo_utilities.get_image_datetime_str(fullname)
            image_ModelID = _photo_utilities.get_image_Model_name(fullname).replace(' ','')
            image_Software = _photo_utilities.get_image_Software(fullname)
            #print("image_datetime :", image_datetime)
            
            image_dt = datetime.strptime(image_datetime, '%Y%m%d-%H%M%S')
            # print("image_dt :", image_dt)
            # print(f"image_dt.month : {image_dt.month:02d}")
            # print(f"image_dt.day : {image_dt.day:02d}")
            SAVEDIR = (BASEDIR/ str(image_dt.year) / f'{(image_dt.month):02d}' / f'{(image_dt.day):02d}_{image_ModelID}')
            new_fname = f'{image_datetime}_{image_ModelID}_py{fpath.suffix}'
            new_fpath = SAVEDIR / new_fname
            print("new_fpath :", new_fpath)
            for i in range(3, -1, -1):
                if not new_fpath.parents[i].exists() :
                    os.mkdir(str(new_fpath.parents[i]))
                    #print(f'{str(new_fpath.parents[i])} is created...')
                else :
                    #print(f'{str(new_fpath.parents[i])} is exist...')
                    pass
            if not new_fpath.exists() :
                print(f'{str(new_fpath)} is not exist...')
            else : 
                print(f'{str(new_fpath)} is already exist...')
                new_date = datetime.strftime(datetime.now(), '%Y%m%d%H%M%S')
                new_fpath = new_fpath.parents[0] / f'{new_fpath.stem}_{new_date}{new_fpath.suffix}'
            shutil.move(str(fpath), str(new_fpath))
        except Exception as err :
            print(err)   
    if fpath.suffix.lower() == '.png' :
        try: 
            image_datetime = _photo_utilities.get_image_datetime_str(fullname)
            image_ModelID = _photo_utilities.get_image_Model_name(fullname).replace(' ','')
            image_Software = _photo_utilities.get_image_Software(fullname)
            #print("image_datetime :", image_datetime)
            
            image_dt = datetime.strptime(image_datetime, '%Y%m%d-%H%M%S')
            # print("image_dt :", image_dt)
            # print(f"image_dt.month : {image_dt.month:02d}")
            # print(f"image_dt.day : {image_dt.day:02d}")
            SAVEDIR = (BASEDIR/ str(image_dt.year) / f'{(image_dt.month):02d}' / f'{(image_dt.day):02d}_{image_ModelID}')
            new_fname = f'{image_datetime}_{image_ModelID}_py{fpath.suffix}'
            new_fpath = SAVEDIR / new_fname
            print("new_fpath :", new_fpath)
            for i in range(3, -1, -1):
                if not new_fpath.parents[i].exists() :
                    os.mkdir(str(new_fpath.parents[i]))
                    #print(f'{str(new_fpath.parents[i])} is created...')
                else :
                    #print(f'{str(new_fpath.parents[i])} is exist...')
                    pass
            if not new_fpath.exists() :
                print(f'{str(new_fpath)} is not exist...')
            else : 
                print(f'{str(new_fpath)} is already exist...')
                new_date = datetime.strftime(datetime.now(), '%Y%m%d%H%M%S')
                new_fpath = new_fpath.parents[0] / f'{new_fpath.stem}_{new_date}{new_fpath.suffix}'
            shutil.move(str(fpath), str(new_fpath))
        except Exception as err :
            print(err)
# Out:
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# mov_datetime : 20230928-203845
# new_fpath : /mnt/photo/2023/09/28/20230928-203845_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203845_py.MOV is already exist...
# mov_datetime : 20230928-203843
# new_fpath : /mnt/photo/2023/09/28/20230928-203843_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203843_py.MOV is already exist...
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# mov_datetime : 20230928-203827
# new_fpath : /mnt/photo/2023/09/28/20230928-203827_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203827_py.MOV is already exist...
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# mov_datetime : 20230928-203825
# new_fpath : /mnt/photo/2023/09/28/20230928-203825_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203825_py.MOV is already exist...
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# mov_datetime : 20230928-203819
# new_fpath : /mnt/photo/2023/09/28/20230928-203819_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203819_py.MOV is already exist...
# mov_datetime : 20230928-203819
# new_fpath : /mnt/photo/2023/09/28/20230928-203819_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203819_py.MOV is already exist...
# [Errno 2] No such file or directory: '/mnt/photo/2023/09/28/20230928-203819_py_20230928213601.MOV'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# mov_datetime : 20230928-203859
# new_fpath : /mnt/photo/2023/09/28/20230928-203859_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203859_py.MOV is already exist...
# mov_datetime : 20230928-203859
# new_fpath : /mnt/photo/2023/09/28/20230928-203859_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2023 is exist...
# /mnt/photo/2023/09 is exist...
# /mnt/photo/2023/09/28 is exist...
# /mnt/photo/2023/09/28/20230928-203859_py.MOV is already exist...
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# mov_datetime : 20220411-202122
# new_fpath : /mnt/photo/2022/04/11/20220411-202122_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202122_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1539.MOV'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-111904_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-111904_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202121
# new_fpath : /mnt/photo/2022/04/11/20220411-202121_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202121_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1540.MOV'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-124148_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-124148_APPLE_iPhone6s_py.JPG is already exist...
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-132916_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-132916_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202111
# new_fpath : /mnt/photo/2022/04/11/20220411-202111_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202111_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1542.MOV'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-132916_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-132916_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202121
# new_fpath : /mnt/photo/2022/04/11/20220411-202121_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202121_py.MOV is already exist...
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-150708_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-150708_APPLE_iPhone6s_py.JPG is already exist...
# PNG file does not have exif data.
# PNG file does not have exif data.
# PNG file does not have exif data.
# mov_datetime : 20220411-202106
# new_fpath : /mnt/photo/2022/04/11/20220411-202106_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202106_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1544.MOV'
# time data '00000000-000000' does not match format '%Y%m%d-%H%M%S'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173714_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173714_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202109
# new_fpath : /mnt/photo/2022/04/11/20220411-202109_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202109_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1546.MOV'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173717_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173717_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202141
# new_fpath : /mnt/photo/2022/04/11/20220411-202141_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202141_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1547.MOV'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173718_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173718_APPLE_iPhone6s_py.JPG is already exist...
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173724_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173724_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202126
# new_fpath : /mnt/photo/2022/04/11/20220411-202126_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202126_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1549.MOV'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173818_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-173818_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202115
# new_fpath : /mnt/photo/2022/04/11/20220411-202115_py.MOV
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/04 is exist...
# /mnt/photo/2022/04/11 is exist...
# /mnt/photo/2022/04/11/20220411-202115_py.MOV is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/iCloud Photos/Downloads/IMG_1550.MOV'
# new_fpath : /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-175316_APPLE_iPhone6s_py.JPG
# /mnt/photo is exist...
# /mnt/photo/2018 is exist...
# /mnt/photo/2018/01 is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s is exist...
# /mnt/photo/2018/01/17_APPLE_iPhone6s/20180117-175316_APPLE_iPhone6s_py.JPG is already exist...
# mov_datetime : 20220411-202120
# new_fpath : /mnt/photo/2022/04/11/20220411-202120_py.MOV
# /mnt/photo is exist...
# ...
# /mnt/photo/2021 is exist...
# /mnt/photo/2021/01 is exist...
# /mnt/photo/2021/01/07 is exist...
# /mnt/photo/2021/01/07/20210107-182552_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-06-25/20220625-080148_00000125_py.mp4'
# mov_datetime : 20210107-182854
# new_fpath : /mnt/photo/2021/01/07/20210107-182854_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2021 is exist...
# /mnt/photo/2021/01 is exist...
# /mnt/photo/2021/01/07 is exist...
# /mnt/photo/2021/01/07/20210107-182854_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-06-25/20220625-080148_00000126_py.mp4'
# mov_datetime : 20210507-174718
# new_fpath : /mnt/photo/2021/05/07/20210507-174718_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2021 is exist...
# /mnt/photo/2021/05 is exist...
# /mnt/photo/2021/05/07 is exist...
# /mnt/photo/2021/05/07/20210507-174718_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-06-25/20220625-080148_00000127_py.mp4'
# mov_datetime : 20210507-175552
# new_fpath : /mnt/photo/2021/05/07/20210507-175552_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2021 is exist...
# /mnt/photo/2021/05 is exist...
# /mnt/photo/2021/05/07 is exist...
# /mnt/photo/2021/05/07/20210507-175552_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-06-25/20220625-080148_00000128_py.mp4'
# mov_datetime : 20080103-094607
# new_fpath : /mnt/photo/2008/01/03/20080103-094607_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is created...
# /mnt/photo/2008/01/03/20080103-094607_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120426_00000038_py.mp4'
# mov_datetime : 20080103-094608
# new_fpath : /mnt/photo/2008/01/03/20080103-094608_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-094608_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120427_00000039_py.mp4'
# mov_datetime : 20080103-095107
# new_fpath : /mnt/photo/2008/01/03/20080103-095107_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-095107_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120450_00000040_py.mp4'
# mov_datetime : 20080103-095108
# new_fpath : /mnt/photo/2008/01/03/20080103-095108_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-095108_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120451_00000041_py.mp4'
# mov_datetime : 20080103-095607
# new_fpath : /mnt/photo/2008/01/03/20080103-095607_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-095607_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120514_00000042_py.mp4'
# mov_datetime : 20080103-095608
# new_fpath : /mnt/photo/2008/01/03/20080103-095608_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-095608_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120515_00000043_py.mp4'
# mov_datetime : 20080103-100107
# new_fpath : /mnt/photo/2008/01/03/20080103-100107_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-100107_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120539_00000044_py.mp4'
# mov_datetime : 20080103-100109
# new_fpath : /mnt/photo/2008/01/03/20080103-100109_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-100109_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120542_00000045_py.mp4'
# mov_datetime : 20080103-100607
# new_fpath : /mnt/photo/2008/01/03/20080103-100607_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-100607_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120605_00000046_py.mp4'
# mov_datetime : 20080103-100609
# new_fpath : /mnt/photo/2008/01/03/20080103-100609_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-100609_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120606_00000047_py.mp4'
# mov_datetime : 20080103-100618
# new_fpath : /mnt/photo/2008/01/03/20080103-100618_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-100618_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120607_00000048_py.mp4'
# mov_datetime : 20080103-100618
# new_fpath : /mnt/photo/2008/01/03/20080103-100618_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2008 is exist...
# /mnt/photo/2008/01 is exist...
# /mnt/photo/2008/01/03 is exist...
# /mnt/photo/2008/01/03/20080103-100618_py.mp4 is already exist...
# mov_datetime : 20220729-072614
# new_fpath : /mnt/photo/2022/07/29/20220729-072614_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is created...
# /mnt/photo/2022/07/29 is created...
# /mnt/photo/2022/07/29/20220729-072614_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120630_00000050_py.mp4'
# mov_datetime : 20220729-072615
# new_fpath : /mnt/photo/2022/07/29/20220729-072615_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-072615_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120631_00000051_py.mp4'
# mov_datetime : 20220729-073114
# new_fpath : /mnt/photo/2022/07/29/20220729-073114_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-073114_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120655_00000052_py.mp4'
# mov_datetime : 20220729-073115
# new_fpath : /mnt/photo/2022/07/29/20220729-073115_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-073115_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120656_00000053_py.mp4'
# mov_datetime : 20220729-073614
# new_fpath : /mnt/photo/2022/07/29/20220729-073614_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-073614_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120719_00000054_py.mp4'
# mov_datetime : 20220729-073615
# new_fpath : /mnt/photo/2022/07/29/20220729-073615_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-073615_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120720_00000055_py.mp4'
# mov_datetime : 20220729-074114
# new_fpath : /mnt/photo/2022/07/29/20220729-074114_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-074114_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120743_00000056_py.mp4'
# mov_datetime : 20220729-074115
# new_fpath : /mnt/photo/2022/07/29/20220729-074115_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-074115_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120744_00000057_py.mp4'
# mov_datetime : 20220729-074614
# new_fpath : /mnt/photo/2022/07/29/20220729-074614_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-074614_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120808_00000058_py.mp4'
# mov_datetime : 20220729-074615
# new_fpath : /mnt/photo/2022/07/29/20220729-074615_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-074615_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120809_00000059_py.mp4'
# mov_datetime : 20220729-075114
# new_fpath : /mnt/photo/2022/07/29/20220729-075114_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-075114_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120832_00000060_py.mp4'
# mov_datetime : 20220729-075115
# new_fpath : /mnt/photo/2022/07/29/20220729-075115_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-075115_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120834_00000061_py.mp4'
# mov_datetime : 20220729-075525
# new_fpath : /mnt/photo/2022/07/29/20220729-075525_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-075525_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120853_00000062_py.mp4'
# mov_datetime : 20220729-075525
# new_fpath : /mnt/photo/2022/07/29/20220729-075525_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/07 is exist...
# /mnt/photo/2022/07/29 is exist...
# /mnt/photo/2022/07/29/20220729-075525_py.mp4 is already exist...
# mov_datetime : 20220801-201015
# new_fpath : /mnt/photo/2022/08/01/20220801-201015_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is created...
# /mnt/photo/2022/08/01/20220801-201015_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120855_00000064_py.mp4'
# mov_datetime : 20220801-201015
# new_fpath : /mnt/photo/2022/08/01/20220801-201015_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-201015_py.mp4 is already exist...
# mov_datetime : 20220801-202429
# new_fpath : /mnt/photo/2022/08/01/20220801-202429_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-202429_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120918_00000066_py.mp4'
# mov_datetime : 20220801-202431
# new_fpath : /mnt/photo/2022/08/01/20220801-202431_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-202431_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120919_00000067_py.mp4'
# mov_datetime : 20220801-202929
# new_fpath : /mnt/photo/2022/08/01/20220801-202929_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-202929_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120942_00000068_py.mp4'
# mov_datetime : 20220801-202931
# new_fpath : /mnt/photo/2022/08/01/20220801-202931_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-202931_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-120943_00000069_py.mp4'
# mov_datetime : 20220801-203430
# new_fpath : /mnt/photo/2022/08/01/20220801-203430_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-203430_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-121006_00000070_py.mp4'
# mov_datetime : 20220801-203431
# new_fpath : /mnt/photo/2022/08/01/20220801-203431_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-203431_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-121007_00000071_py.mp4'
# mov_datetime : 20220801-203930
# new_fpath : /mnt/photo/2022/08/01/20220801-203930_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-203930_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-121030_00000072_py.mp4'
# mov_datetime : 20220801-204027
# new_fpath : /mnt/photo/2022/08/01/20220801-204027_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/01 is exist...
# /mnt/photo/2022/08/01/20220801-204027_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-07/20220807-121036_00000074_py.mp4'
# mov_datetime : 20220811-153010
# new_fpath : /mnt/photo/2022/08/11/20220811-153010_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/11 is exist...
# /mnt/photo/2022/08/11/20220811-153010_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-12/20220812-064020_00000010_py.mp4'
# mov_datetime : 20220811-143712
# new_fpath : /mnt/photo/2022/08/11/20220811-143712_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/11 is exist...
# /mnt/photo/2022/08/11/20220811-143712_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-12/20220812-064050_00000008_py.mp4'
# mov_datetime : 20220811-141104
# new_fpath : /mnt/photo/2022/08/11/20220811-141104_py.mp4
# /mnt/photo is exist...
# /mnt/photo/2022 is exist...
# /mnt/photo/2022/08 is exist...
# /mnt/photo/2022/08/11 is exist...
# /mnt/photo/2022/08/11/20220811-141104_py.mp4 is not exist...
# [Errno 2] No such file or directory: '/mnt/photo/temp_files/mp4file/2022/2022-08-12/20220812-064053_00000006_py.mp4'

# %%
#%%
#############################################################################
# for i in range(4) :
#     fullnames = _Python_utilities.getFullnameListOfallsubDirs(str(NEW_files))
#     print ("fullnames: {}".format(fullnames))
#     for fullname in fullnames[:] :
#         # Check is empty..
#         if len(os.listdir(fullname)) == 0 :
#             shutil.rmtree(r"{}".format(fullname)) # Delete..
#             print ("rmtree {}\n".format(fullname))
for i in range(10):
    DOINGDIR = NEW_files
    DOINGDIRs = sorted(_Python_utilities.getFullnameListOfallsubDirs(DOINGDIR))
    #print ("DOINGDIRs: ", format(DOINGDIRs))
    print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))
    try: 
        for DOINGDIR in DOINGDIRs : 
            if len(os.listdir(str(DOINGDIR))) == 0 :
                shutil.rmtree(f"{str(DOINGDIR)}") # Delete..
                print (f"rmtree {str(DOINGDIR)}")
            else : 
                fpaths = _Python_utilities.getFullnameListOfallFiles(str(DOINGDIR))
                print("fpaths", fpaths)

                for fpath in fpaths[:]:
                    print("fpath", fpath)

                    if fpath[-4:].lower() in [".txt", ".log", ".ini",
                                            ".csv", ".thm" , "proj"] \
                                            and os.path.isfile(fpath):
                        os.remove("{}".format(fpath))
                        print("{} is removed...".format(fpath))
    except Exception as err :
            print(err)
# Out:
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic
# len(DOINGDIRs):  1
# fpaths ['/mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic']
# fpath /mnt/photo/temp_files/2020-05-02_Apple_iPhone-XR_-/20200502-090715_Apple_iPhone-XR_-_00000013_py.heic

# %%
SAVEDIR.parents

# %%
fpath = Path('/mnt/photo/temp_files/movfile/2017/2017-07-20/20170720-050732_00001663_py.mov')
mov_datetime = _photo_utilities.get_mov_creation_date(str(fpath))
mov_datetime
# Out:
# '20170720-140733'

# %%
fpath = Path('/mnt/photo/pngfile/2019/2019-06-21_-_-/20190621-164841_-_-_00001303_py.png')
image_datetime = _photo_utilities.get_image_datetime_str(str(fpath))
print("image_datetime", image_datetime)
image_ModelID = _photo_utilities.get_image_Model_name(str(fpath)).replace(' ','')
print("image_ModelID", image_ModelID)
image_Software = _photo_utilities.get_image_Software(str(fpath))
print("image_Software", image_Software)
# Out:
# image_datetime 20190621-164841
# image_ModelID -
# image_Software -
